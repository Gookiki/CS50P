# %%
question = input("What is the answer to the Great Question of Life, the Universe, and Everything? ")

if question == "42" or question == "fourty two" or question == "fourty-two":
    print("Yes")
else:
    print("no")
# Out:
# no

# %%
greeting = input("What is your greeting? ").lower()

if greeting == "hello":
    print("$100")
elif greeting.startswith("h"):
    print("$20")
else:
    print("Nothing")
# Out:
# $100

# %%
filearray = input("What is the file name? ").lower().split(".")

extension = filearray[-1]

if extension == "gif":
    print("image/gif")
elif extension == "jpg":
    print("image/jpg")
elif extension == "jpeg":
    print("image/jpeg")
elif extension == "png":
    print("image/png")
elif extension == "pdf":
    print("application/pdf")
elif extension == "txt":
    print("text/plain")
elif extension == "zip":
    print("application/zip")
else:
    print("application/octet-stream")
# Out:
# application/octet-stream

# %%
operation = input("Enter your equation: ").split(" ")

x = int(operation[0])
y = operation[1]
z = int(operation[2])

if y == "+":
    print(round(float(x + z), 1))
elif y == "-":
    print(round(float(x - z), 1))
elif y == "*":
    print(round(float(x * z), 1))
elif y == "/":
    print(round(float(x / z), 1))
# Out:
# 1.3

# %%
def main():
    time = input("What is the current time? ")
    value = convert(time)
    if 7 <= value <= 8:
        print("Breakfast")
    elif 12 <= value <= 13:
        print("Lunch")
    elif 18 <= value <= 19:
        print("Dinner")
    else:
        print("Nothing")

def convert(time):
    s = time.strip()
    ampm = ""
    if len(s) > 2 and s[-2:].lower() in ("am", "pm"):
        ampm = s[-2:].lower()
        s = s[:-2].strip()
    hours_str, minutes_str = s.split(":")
    hours = int(hours_str)
    minutes = int(minutes_str) / 60
    if ampm == "pm" and hours != 12:
        hours += 12
    if ampm == "am" and hours == 12:
        hours = 0
    return hours + minutes


main()
# Out:
# Nothing
