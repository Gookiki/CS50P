# %%
# %pip install emoji
# Out:
# Collecting emoji
#   Downloading emoji-2.15.0-py3-none-any.whl.metadata (5.7 kB)
# Downloading emoji-2.15.0-py3-none-any.whl (608 kB)
#    ---------------------------------------- 0.0/608.4 kB ? eta -:--:--
#    ---------------------------------------- 608.4/608.4 kB 13.4 MB/s  0:00:00
# Installing collected packages: emoji
# Successfully installed emoji-2.15.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import emoji

sentence = input("Emojize: ")

print(emoji.emojize(sentence))
# Out:
# 🐼

# %%
# %pip install inflect
# Out:
# Collecting inflect
#   Downloading inflect-7.5.0-py3-none-any.whl.metadata (24 kB)
# Collecting more_itertools>=8.5.0 (from inflect)
#   Downloading more_itertools-11.1.0-py3-none-any.whl.metadata (41 kB)
# Collecting typeguard>=4.0.1 (from inflect)
#   Downloading typeguard-4.5.2-py3-none-any.whl.metadata (3.8 kB)
# Collecting typing_extensions>=4.14.0 (from typeguard>=4.0.1->inflect)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Downloading inflect-7.5.0-py3-none-any.whl (35 kB)
# Downloading more_itertools-11.1.0-py3-none-any.whl (72 kB)
# Downloading typeguard-4.5.2-py3-none-any.whl (36 kB)
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Installing collected packages: typing_extensions, more_itertools, typeguard, inflect
#
#    -------------------- ------------------- 2/4 [typeguard]
#    ------------------------------ --------- 3/4 [inflect]
#    ---------------------------------------- 4/4 [inflect]
#
# Successfully installed inflect-7.5.0 more_itertools-11.1.0 typeguard-4.5.2 typing_extensions-4.15.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import inflect
namelist = []
while True:
    namelist.append(input("Name: "))
    if namelist[-1] == "q":
        break
formatted = inflect.engine().join(namelist[:-1])
print("Adieu, adieu, to", end=" ")
print(formatted)
# Out:
# ---------------------------------------------------------------------------
# TypeCheckError                            Traceback (most recent call last)
# Cell In[10], line 7
#       3 while True:
#       4     namelist.append(input("Name: "))
#       5     if namelist[-1] == "q":
#       6         break
# ----> 7 formatted = inflect.engine().join(namelist[:-1])
#       8 print("Adieu, adieu, to", end=" ")
#       9 print(formatted)
#
# File c:\Users\marse\VSCRepository\CS50P\CS50P\.venv\Lib\site-packages\inflect\__init__.py:3955, in join(self, words, sep, sep_spaced, final_sep, conj, conj_spaced)
#    3951             yield comma
#    3952         yield f" {nc}"
#    3954 @typechecked
# -> 3955 def join(
#    3956     self,
#    3957     words: Optional[Sequence[Word]],
#    3958     sep: Optional[str] = None,
#    3959     sep_spaced: bool = True,
#    3960     final_sep: Optional[str] = None,
#    3961     conj: str = "and",
#    3962     conj_spaced: bool = True,
#    3963 ) -> str:
#    3964     """
#    3965     Join words into a list.
#    3966
#    (...)   3974
#    3975     """
#    3976     if not words:
#
# File c:\Users\marse\VSCRepository\CS50P\CS50P\.venv\Lib\site-packages\typeguard\_functions.py:180, in check_argument_types_internal(func_name, arguments, memo)
#     177         raise exc
#     179 try:
# --> 180     check_type_internal(value, annotation, memo)
#     181 except TypeCheckError as exc:
#     182     qualname = qualified_name(value, add_class_prefix=True)
#
# File c:\Users\marse\VSCRepository\CS50P\CS50P\.venv\Lib\site-packages\typeguard\_checkers.py:989, in check_type_internal(value, annotation, memo)
#     987     checker = lookup_func(origin_type, args, extras)
#     988     if checker:
# --> 989         checker(value, origin_type, args, memo)
#     990         return
#     992 if isclass(origin_type):
#
# File c:\Users\marse\VSCRepository\CS50P\CS50P\.venv\Lib\site-packages\typeguard\_checkers.py:471, in check_uniontype(value, origin_type, args, memo)
#     468 finally:
#     469     del errors  # avoid creating ref cycle
# --> 471 raise TypeCheckError(f"did not match any element in the union:\n{formatted_errors}")
#
# TypeCheckError: argument "words" (list) did not match any element in the union:
#   Sequence[inflect.Word]: item 0 is not an instance of inflect.Word
#   NoneType: is not an instance of NoneType
